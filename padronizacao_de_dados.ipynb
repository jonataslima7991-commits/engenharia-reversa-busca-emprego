# %%
import pandas as pd
import numpy as np

df_vagas = pd.read_csv("progresso_scraper_v3.csv", low_memory=False)
display(df_vagas)
# Out:
#                                                  Titulo  \
# 0     Estágio em Ciência de Dados - Híbrido, SP | Id...
# 1     Bolsista Graduado [Ciência de dados, Sistemas ...
# 2                                     ANALISTA DE DADOS
# 3     Bolsista Mestre (Estatística / Matemática / En...
# 4                      Especialista em Ciência de Dados
# ...                                                 ...
# 4995  Bolsista Mestre - [Administração, Ciências de ...
# 4996                                   Estágio em Dados
# 4997  Bolsista Graduando [Engenharia, Ciência de Dad...
# 4998  Especialista de Dados de Suprimentos - Análise...
# 4999                                  Analista de Dados
#
#                                             Link_Adzuna  \
# 0          https://www.adzuna.com.br/details/5655209645
# 1          https://www.adzuna.com.br/details/5489220352
# 2          https://www.adzuna.com.br/details/5621629728
# 3          https://www.adzuna.com.br/details/3156436582
# ...
